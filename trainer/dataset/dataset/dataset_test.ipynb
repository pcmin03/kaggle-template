# %%
import torch
import torchvision
import torchvision.transforms as transforms
import logging
import os
import pandas as pd

# %%
dataset = torchvision.datasets.VOCSegmentation(
    root='/nfs3/personal/cmpark/project/ncc-atrophy/endoscopy/test', 
    download=False, 
    image_set= 'val'
    )

# %%
import matplotlib.pyplot as plt
img,label = next(iter(dataset))
fig,axs = plt.subplots(1,2,figsize=(10,10))
axs[0].imshow(img)
axs[1].imshow(label)
